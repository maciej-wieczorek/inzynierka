# %%
import pandas as pd
import matplotlib.pyplot as plt
from graph_drawer import draw
from classifier import train_model

# %% [markdown]
# # View data

# %%
df = pd.read_csv('graphs.csv')
df.head(5)
# Out:
#                 client             server  \
# 0  192.168.0.100:62310  52.223.194.27:443
# 1  192.168.0.100:62310  52.223.194.27:443
# 2  192.168.0.100:62310  52.223.194.27:443
# 3  192.168.0.100:62310  52.223.194.27:443
# 4  192.168.0.100:62310  52.223.194.27:443
#
#                                                graph
# 0  0,1,1 0,2,5 0,3,0.72 0,4,3 0,6,1.33333 0,7,0 0...
# 1  0,1,0 0,2,0 0,3,0.52381 0,7,0 0,8,0 0,9,0 0,10...
# 2  0,1,0 0,2,28 0,3,0 0,4,2 0,6,0 0,7,1.5 0,9,3 0...
# 3  0,1,0.5 0,2,0 0,3,0 0,4,5.5 0,5,0 0,6,0 0,7,0 ...
# 4  0,1,0 0,2,27.3333 0,3,0.0434783 0,4,1 0,7,0 0,...

# %% [markdown]
# # Test GNN model

# %%
train_model()
# Out:
# Full dataset = 1026 graphs
# Class 0 (Twitch.tv): 800 77.97%
# Class 1 (Other): 226 22.03%
#
# Training set = 820 graphs
# Class 0 (Twitch.tv): 639 77.93%
# Class 1 (Other): 181 22.07%
#
# Validation set = 103 graphs
# Class 0 (Twitch.tv): 79 76.7%
# Class 1 (Other): 24 23.3%
#
# Test set = 103 graphs
# Class 0 (Twitch.tv): 82 79.61%
# Class 1 (Other): 21 20.39%
#
# Epoch   0 | Train Loss: 0.57 | Train Acc: 78.63% | Val Loss: 0.47 | Val Acc: 81.93%
# Epoch  20 | Train Loss: 0.35 | Train Acc: 95.77% | Val Loss: 0.36 | Val Acc: 94.59%
# Epoch  40 | Train Loss: 0.34 | Train Acc: 97.57% | Val Loss: 0.37 | Val Acc: 94.59%
# Epoch  60 | Train Loss: 0.34 | Train Acc: 97.69% | Val Loss: 0.36 | Val Acc: 95.09%
# Epoch  80 | Train Loss: 0.32 | Train Acc: 98.92% | Val Loss: 0.36 | Val Acc: 95.59%
# Epoch 100 | Train Loss: 0.33 | Train Acc: 98.32% | Val Loss: 0.36 | Val Acc: 95.09%
# Test Loss: 0.34 | Test Acc: 97.16%

# %% [markdown]
# # Draw graphs

# %%
plt.figure(figsize=(12, 8))
draw(df.iloc[4]['graph'])
draw(df.iloc[5]['graph'])
